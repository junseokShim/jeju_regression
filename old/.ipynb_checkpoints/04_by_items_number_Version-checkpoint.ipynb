# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
import holidays

from sklearn.preprocessing import LabelEncoder

warnings.filterwarnings(action='ignore')

# %%
path = f'./processed_data/train_merge.csv'
df = pd.read_csv(path)
df = df[df['item']=='BC']
df[~df["Date"].isin(kr_holidays)]

for i in qual_col:
    le = LabelEncoder()
    df[i]=le.fit_transform(df[i])

name_lst = df.corr()['price(원/kg)'].sort_values().keys().to_list()
value_lst = df.corr()['price(원/kg)'].sort_values().values

print([a for a, b in zip(name_lst, value_lst) if abs(b)>0.15 and a != 'supply(kg)_x' ])
# Out:
# ['location', 'week', 'supply(kg)_y', 'price(원/kg)']

# %%
# 필요 정보
# item_lst : item 리스트 항목
# qual_col : one-hot-encoder 변환이 필요한 항목

item_lst = ['TG', 'CR', 'CB', 'RD', 'BC']
qual_col = ['item', 'corporation', 'location','day_name', 'holiday']
columns_dict = {
    'TG' : ['year', 'month', 'day', 'location', 'corporation', 'supply(kg)_y', '수출 금액', '무역수지', '전체 거래량', '수출 중량', 'price(원/kg)'],
    'CR' : ['location', 'week', 'month', 'corporation', 'year', 'supply(kg)_y', 'price(원/kg)'],
    'CB' : ['month', 'week', 'location', '무역수지', '수출 금액', '수출 중량', 'corporation', 'supply(kg)_y', 'price(원/kg)'],
    'RD' : ['week', 'month', 'location', 'supply(kg)_y', 'price(원/kg)'],
    'BC' : ['location', 'week', 'supply(kg)_y', 'price(원/kg)']
}

# item 선택
item = item_lst[0]
path = f'./processed_data/{item}_train_merge.csv'

# 한국 2019~2023 공휴일 정보
kr_holidays = holidays.KR(years=[2019,2020,2021,2022,2023])
#kr_holidays = [str(i) for i in kr_holidays]
kr_holidays = {str(i):kr_holidays[i] for i in kr_holidays}

# %%
train = pd.read_csv(path)

# 데이터 전처리 프로세스
train['holiday'] = [kr_holidays[i] if i in list(kr_holidays.keys()) else 'None' for i in train['timestamp']]

for i in qual_col:
    le = LabelEncoder()
    train[i]=le.fit_transform(train[i])

train = train[columns_dict[item]]

# %%
from pycaret.regression import *

s = setup(train, target = 'price(원/kg)', 
        session_id = 41, 
        fold = 10, 
        normalize = True, 
        normalize_method = 'minmax',
        train_size=0.8)

TG_reg = compare_models()
# Out:
# <style type="text/css">
# #T_efb24_row8_col1, #T_efb24_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_efb24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efb24_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_efb24_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efb24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efb24_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_efb24_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efb24_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_efb24_row1_col1" class="data row1 col1" >price(원/kg)</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efb24_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_efb24_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efb24_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_efb24_row3_col1" class="data row3 col1" >(15230, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efb24_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_efb24_row4_col1" class="data row4 col1" >(15230, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_efb24_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_efb24_row5_col1" class="data row5 col1" >(12184, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_efb24_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_efb24_row6_col1" class="data row6 col1" >(3046, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_efb24_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_efb24_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_efb24_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_efb24_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_efb24_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_efb24_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_efb24_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_efb24_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_efb24_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_efb24_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_efb24_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_efb24_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_efb24_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_efb24_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_efb24_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_efb24_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_efb24_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_efb24_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_efb24_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_efb24_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_efb24_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_efb24_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_efb24_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_efb24_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_efb24_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_efb24_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_efb24_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_efb24_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_efb24_row20_col1" class="data row20 col1" >df0a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e4583 th {
#   text-align: left;
# }
# #T_e4583_row0_col0, #T_e4583_row1_col0, #T_e4583_row1_col1, #T_e4583_row1_col2, #T_e4583_row1_col3, #T_e4583_row1_col4, #T_e4583_row1_col5, #T_e4583_row1_col6, #T_e4583_row2_col0, #T_e4583_row2_col1, #T_e4583_row2_col2, #T_e4583_row2_col3, #T_e4583_row2_col4, #T_e4583_row2_col5, #T_e4583_row2_col6, #T_e4583_row3_col0, #T_e4583_row3_col1, #T_e4583_row3_col2, #T_e4583_row3_col3, #T_e4583_row3_col4, #T_e4583_row3_col5, #T_e4583_row3_col6, #T_e4583_row4_col0, #T_e4583_row4_col1, #T_e4583_row4_col2, #T_e4583_row4_col3, #T_e4583_row4_col4, #T_e4583_row4_col5, #T_e4583_row4_col6, #T_e4583_row5_col0, #T_e4583_row5_col1, #T_e4583_row5_col2, #T_e4583_row5_col3, #T_e4583_row5_col4, #T_e4583_row5_col5, #T_e4583_row5_col6, #T_e4583_row6_col0, #T_e4583_row6_col1, #T_e4583_row6_col2, #T_e4583_row6_col3, #T_e4583_row6_col4, #T_e4583_row6_col5, #T_e4583_row6_col6, #T_e4583_row7_col0, #T_e4583_row7_col1, #T_e4583_row7_col2, #T_e4583_row7_col3, #T_e4583_row7_col4, #T_e4583_row7_col5, #T_e4583_row7_col6, #T_e4583_row8_col0, #T_e4583_row8_col1, #T_e4583_row8_col2, #T_e4583_row8_col3, #T_e4583_row8_col4, #T_e4583_row8_col5, #T_e4583_row8_col6, #T_e4583_row9_col0, #T_e4583_row9_col1, #T_e4583_row9_col2, #T_e4583_row9_col3, #T_e4583_row9_col4, #T_e4583_row9_col5, #T_e4583_row9_col6, #T_e4583_row10_col0, #T_e4583_row10_col1, #T_e4583_row10_col2, #T_e4583_row10_col3, #T_e4583_row10_col4, #T_e4583_row10_col5, #T_e4583_row10_col6, #T_e4583_row11_col0, #T_e4583_row11_col1, #T_e4583_row11_col2, #T_e4583_row11_col3, #T_e4583_row11_col4, #T_e4583_row11_col5, #T_e4583_row11_col6, #T_e4583_row12_col0, #T_e4583_row12_col1, #T_e4583_row12_col2, #T_e4583_row12_col3, #T_e4583_row12_col4, #T_e4583_row12_col5, #T_e4583_row12_col6, #T_e4583_row13_col0, #T_e4583_row13_col1, #T_e4583_row13_col2, #T_e4583_row13_col3, #T_e4583_row13_col4, #T_e4583_row13_col5, #T_e4583_row13_col6, #T_e4583_row14_col0, #T_e4583_row14_col1, #T_e4583_row14_col2, #T_e4583_row14_col3, #T_e4583_row14_col4, #T_e4583_row14_col5, #T_e4583_row14_col6, #T_e4583_row15_col0, #T_e4583_row15_col1, #T_e4583_row15_col2, #T_e4583_row15_col3, #T_e4583_row15_col4, #T_e4583_row15_col5, #T_e4583_row15_col6, #T_e4583_row16_col0, #T_e4583_row16_col1, #T_e4583_row16_col2, #T_e4583_row16_col3, #T_e4583_row16_col4, #T_e4583_row16_col5, #T_e4583_row16_col6, #T_e4583_row17_col0, #T_e4583_row17_col1, #T_e4583_row17_col2, #T_e4583_row17_col3, #T_e4583_row17_col4, #T_e4583_row17_col5, #T_e4583_row17_col6, #T_e4583_row18_col0, #T_e4583_row18_col1, #T_e4583_row18_col2, #T_e4583_row18_col3, #T_e4583_row18_col4, #T_e4583_row18_col5, #T_e4583_row18_col6, #T_e4583_row19_col0, #T_e4583_row19_col1, #T_e4583_row19_col2, #T_e4583_row19_col3, #T_e4583_row19_col4, #T_e4583_row19_col5, #T_e4583_row19_col6 {
#   text-align: left;
# }
# #T_e4583_row0_col1, #T_e4583_row0_col2, #T_e4583_row0_col3, #T_e4583_row0_col4, #T_e4583_row0_col5, #T_e4583_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_